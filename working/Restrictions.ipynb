# %%
import pandas as pd
import module
from importlib import reload
reload(module)
# Out:
# <module 'module' from '/Users/shbae/Downloads/coronascan_py/working/module.py'>

# %%
#### 입국 금지 : prohibitions #####

#load sheets
sheets = module.load_excel().worksheets[:1]

#create dataframe
prohibitions = pd.DataFrame()

#add data and delete garbage
data, prohibitions = module.del_garbages(module.add_data(sheets), prohibitions)

#add restrictions state : 0
prohibitions['state'] = 0
#restrictions['tooltip'] = "입국 금지"

#add english nationalities
prohibitions = module.add_nation_eng(prohibitions)

#print dataframe
#prohibitions

# %%
#### 입국 제한 #####

#load sheets
sheets = module.load_excel().worksheets[2:]

#create dataframe
restrictions = pd.DataFrame()

#add data and delete garbage
data, restrictions = module.del_garbages(module.add_data(sheets), restrictions)

#add restrictions state : 0
restrictions['state'] = 1
restrictions['tooltip'] = "입국 제한"

#add english nationalities
restrictions = module.add_nation_eng(restrictions)

#print dataframe
#restrictions

# %%
result = pd.concat([restrictions,prohibitions], axis=0)
#result = result.reset_index(drop = True)
result
# Out:
#    nation_kr                                             detail  state  \
# 0       상하이시  ▸상하이시  진입시,  최근  14일  내  한국,  일본,  이탈리아,  이란, ...      1
# 1        장쑤성  ▸난징공항,  한국  및  일본발  항공기  탑승  내외국민  14일간  지정호텔에...      1
# 2        저장성  ▸원저우공항/항저우공항,   한국발   항공기   탑승   내외국민   14일간  ...      1
# 3        쓰촨성  ▸청두공항,  한국  및  일본발  항공기  탑승  내외국민  지정호텔로  이동하여...      1
# 4        충칭시  ▸충칭공항,   국제선   탑승   내외국민   지정호텔로   이동하여   핵산검사...      1
# ..       ...                                                ...    ...
# 54       세이셸  ▸입국  전  14일  이내  한국,  중국,  홍콩,  마카오,  이란  등을  ...      0
# 55        수단  ▸한국,  중국,  일본,  이탈리아,  이란,  프랑스,  스페인,  이집트를  ...      0
# 56       앙골라  ▸한국,  중국,  이란,  이탈리아를  방문  후  입국한  외국인  (여행,  ...      0
# 57      적도기니  ▸한국,  중국,  이란,  이탈리아,  싱가포르를 방문 후 입국한 외국인 대상 입...      0
# 58       코모로  ▸입국  전  14일  이내  한국  등을  방문  후  입국한  외국인  대상  ...      0
#
#    tooltip marker nation_eng
# 0    입국 제한   True        NaN
# 1    입국 제한   True        NaN
# 2    입국 제한   True        NaN
# 3    입국 제한   True        NaN
# 4    입국 제한   True        NaN
# ..     ...    ...        ...
# 54     NaN  False        SYC
# 55     NaN  False        SDN
# 56     NaN  False        AGO
# 57     NaN   True        NaN
# 58     NaN  False        COM
#
# [138 rows x 6 columns]

# %%
result.to_csv("output.csv")
