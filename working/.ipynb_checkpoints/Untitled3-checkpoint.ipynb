# %%
import openpyxl
import pandas as pd
import json
import yaml

# %%
filename = "test.xlsx"
book = openpyxl.load_workbook(filename)
#sheet = book.worksheets[0]
sheets = book.worksheets

# %%
data = []
for sheet in sheets :
    for row in sheet.rows:
        data.append([row[1].value, row[2].value])
del data[:8]

# %%
dataf = pd.DataFrame()
for index, row in enumerate(data) :
    if row[0] == None or row[1] == '조  치  사  항' :
        del data[index]
        continue
    dataf.at[index, 'nation_kr'] = row[0]
    dataf.at[index, 'detail'] = row[1]
dataf = dataf.reset_index(drop = True)

# %%
filename = "ISO국가코드.xlsx"
book = openpyxl.load_workbook(filename)
sheet = book.worksheets[0]
countries = []
for row in sheet.rows:
    countries.append([row[3].value, row[1].value])
del countries[:4]

countries = dict(countries)

# %%
for index, row in enumerate(data) :
    if row[0] in countries : 
        dataf.at[index, 'nation_eng'] = countries[row[0]]
        dataf.at[index, 'marker'] = False
    else:
        dataf.at[index, 'marker'] = True
dataf
# Out:
#     nation_kr                                             detail nation_eng  \
# 0         나우루  ▸입국  전  21일  이내  한국,  중국,  홍콩,  마카오,  이탈리아를  방...        NRU
# 1        마셜제도  ▸2019.12.31.  이후  한국,  중국,  홍콩,  마카오,  이탈리아,  ...        NaN
# 2    마이크로 네시아  ▸입국  전  14일  이내  한국  등을  방문  후  입국한  외국인  대상  ...        NaN
# 3          몽골  ▸2.27.-3.11.  간  입국  전  14일  이내  한국,  중국,  이탈리...        MNG
# 4        바누아투  ▸입국  전  14일  이내  한국,  중국,  대만,  홍콩,  마카오,  일본,...        VUT
# ..        ...                                                ...        ...
# 212       NaN                                                NaN        MDV
# 213       NaN                                                NaN        MMR
# 214       NaN                                                NaN        IDN
# 215       NaN                                                NaN        JPN
# 216       NaN                                                NaN        PHL
#
#     marker
# 0    False
# 1     True
# 2     True
# 3    False
# 4    False
# ..     ...
# 212  False
# 213  False
# 214  False
# 215  False
# 216  False
#
# [217 rows x 4 columns]

# %%
dataf.to_csv('output.csv')
