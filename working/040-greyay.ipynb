# %%
import csv
import pandas as pd
import re
import json
import pymongo
from pymongo import MongoClient

# %%
#csv
#dataf = pd.read_csv("./restriction_2_0314.csv", encoding='utf-8')
dataf = pd.read_csv("./040_0317.csv", encoding='utf-8')

# %%
# restrictions
#dataf['listview'] = False
# _2 _3
#dataf['state'] = 1
#dataf['tooltip'] = "입국 제한"

#_1
#dataf['state'] = 0
#dataf['tooltip'] = "입국 금지"

# %%
dataf = dataf.replace('\n',' ', regex=True)

# %%
for index, row in dataf.iterrows():
    dataf.at[index, 'detail'] = re.sub('[^가-힣0-9a-zA-Z\\s\\-.]', ' ', row['detail'])

# %%
dataf.astype(str).values.flatten().tolist()
dataf['detail'][1]
# Out:
# '전 중국지역에 여행경보 2단계 여행자제  발령입국 후 자가진단 앱 설치 후 매일 건강 상태 제출 의무'

# %%
dataf
# Out:
#     date continent nation_kr nation_eng  state  \
# 0   1.28       아시아       후베이     CHN-42      3
# 1   1.28       아시아        중국        CHN      2
# 2   3.08       아시아        일본        JPN      2
# 3   3.16        유럽       그리스      \tGRC      2
# 4   3.16        유럽      네덜란드        NLD      2
# 5   3.16        유럽       덴마크        DNK      2
# 6   3.16        유럽        독일        DEU      2
# 7   3.16        유럽      라트비아        LVA      2
# 8   3.16        유럽      루마니아        ROU      2
# 9   3.16        유럽     룩셈부르크      \tLUX      2
# 10  3.16        유럽     리투아니아      \tLTU      2
# 11  3.16        유럽        몰타        MLT      2
# 12  3.16        유럽       벨기에        BEL      2
# 13  3.16        유럽      불가리아        BGR      2
# 14  3.16        유럽     사이프러스        CYP      2
# 15  3.16        유럽       스웨덴        SWE      2
# 16  3.16        유럽       스위스        CHE      2
# 17  3.16        유럽       스페인        ESP      2
# 18  3.16        유럽     슬로바키아      \tSVK      2
# ...

# %%
dataf.to_csv("output_040_0317.csv",index=False)

# %%
client = MongoClient()
client = MongoClient('mongodb://coronascan:corona19scan@cluster0-shard-00-00-emxux.mongodb.net:27017,cluster0-shard-00-01-emxux.mongodb.net:27017,cluster0-shard-00-02-emxux.mongodb.net:27017/coronascan?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin&retryWrites=true&w=majority')

# %%
db = client["coronascan"]

# %%
## 040: warnings, 041: specials 
warn = db.warnings
warn.delete_many({})
csvfile = pd.read_csv("./output_040_0317.csv", encoding='utf-8')
data_json = json.loads(csvfile.to_json(orient='records'))
warn.insert_many(data_json)

# %%
warn.estimated_document_count() # 콜렉션 내 문서 갯수 확인
# Out:
# 39
